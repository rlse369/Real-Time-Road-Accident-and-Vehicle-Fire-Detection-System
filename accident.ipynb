# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Fri Mar 22 05:35:21 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
directory = os.getcwd()
print(directory)
# Out:
# /content

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
from time import perf_counter
import os
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from tensorflow.keras.utils import plot_model

# %%
## Defining batch specfications
batch_size = 100
img_height = 250
img_width = 250

# %%
## loading validation dataset
validation_data =  tf.keras.preprocessing.image_dataset_from_directory(
    '/content/drive/MyDrive/data 2/val',
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 98 files belonging to 2 classes.

# %%
## loading testing dataset
testing_data = tf.keras.preprocessing.image_dataset_from_directory(
    '/content/drive/MyDrive/data 2/test',
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 100 files belonging to 2 classes.

# %%
## loading testing dataset
training_data = tf.keras.preprocessing.image_dataset_from_directory(
    '/content/drive/MyDrive/data 2/train',
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 791 files belonging to 2 classes.

# %%
testing_data
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 250, 250, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
class_names = training_data.class_names
class_names
# Out:
# ['Accident', 'Non Accident']

# %%
## Configuring dataset for performance
AUTOTUNE = tf.data.experimental.AUTOTUNE
training_data = training_data.cache().prefetch(buffer_size=AUTOTUNE)
testing_data = testing_data.cache().prefetch(buffer_size=AUTOTUNE)

# %%
## Defining Cnn
model = tf.keras.models.Sequential([
  layers.BatchNormalization(),
  layers.Conv2D(32, 3, activation='relu'), # Conv2D(f_size, filter_size, activation) # relu, sigmoid, softmax
  layers.MaxPooling2D(), # MaxPooling
  layers.Conv2D(64, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(256, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(512, activation='relu'),
  layers.Dense(len(class_names), activation= 'softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.build((None, 250, 250, 3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (Batch  (None, 250, 250, 3)       12
#  Normalization)
#
#  conv2d (Conv2D)             (None, 248, 248, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 124, 124, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 122, 122, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 61, 61, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 59, 59, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 29, 29, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 27, 27, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 13, 13, 256)       0
#  g2D)
#
#  flatten (Flatten)           (None, 43264)             0
#
#  dense (Dense)               (None, 512)               22151680
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 22541134 (85.99 MB)
# Trainable params: 22541128 (85.99 MB)
# Non-trainable params: 6 (24.00 Byte)
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True)

# %%
## lets train our CNN
checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
history = model.fit(training_data, validation_data=validation_data, epochs = 20, callbacks=callbacks_list)
# Out:
# Epoch 1/20
# 8/8 [==============================] - ETA: 0s - loss: 2.6032 - accuracy: 0.4766
# Epoch 1: val_accuracy improved from -inf to 0.46939, saving model to model_weights.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 8/8 [==============================] - 176s 4s/step - loss: 2.6032 - accuracy: 0.4766 - val_loss: 0.7281 - val_accuracy: 0.4694
# Epoch 2/20
# 8/8 [==============================] - ETA: 0s - loss: 0.6811 - accuracy: 0.5676
# Epoch 2: val_accuracy did not improve from 0.46939
# 8/8 [==============================] - 2s 306ms/step - loss: 0.6811 - accuracy: 0.5676 - val_loss: 0.7515 - val_accuracy: 0.4694
# Epoch 3/20
# 8/8 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.6536
# Epoch 3: val_accuracy did not improve from 0.46939
# 8/8 [==============================] - 3s 389ms/step - loss: 0.6400 - accuracy: 0.6536 - val_loss: 1.1617 - val_accuracy: 0.4694
# Epoch 4/20
# 8/8 [==============================] - ETA: 0s - loss: 0.5745 - accuracy: 0.7067
# Epoch 4: val_accuracy improved from 0.46939 to 0.57143, saving model to model_weights.h5
# 8/8 [==============================] - 3s 395ms/step - loss: 0.5745 - accuracy: 0.7067 - val_loss: 0.8314 - val_accuracy: 0.5714
# Epoch 5/20
# 8/8 [==============================] - ETA: 0s - loss: 0.5185 - accuracy: 0.7560
# Epoch 5: val_accuracy did not improve from 0.57143
# 8/8 [==============================] - 2s 309ms/step - loss: 0.5185 - accuracy: 0.7560 - val_loss: 1.1070 - val_accuracy: 0.5204
# Epoch 6/20
# 8/8 [==============================] - ETA: 0s - loss: 0.4388 - accuracy: 0.8015
# Epoch 6: val_accuracy improved from 0.57143 to 0.62245, saving model to model_weights.h5
# 8/8 [==============================] - 3s 395ms/step - loss: 0.4388 - accuracy: 0.8015 - val_loss: 0.9297 - val_accuracy: 0.6224
# Epoch 7/20
# 8/8 [==============================] - ETA: 0s - loss: 0.3447 - accuracy: 0.8483
# Epoch 7: val_accuracy did not improve from 0.62245
# 8/8 [==============================] - 3s 357ms/step - loss: 0.3447 - accuracy: 0.8483 - val_loss: 1.6782 - val_accuracy: 0.5612
# Epoch 8/20
# 8/8 [==============================] - ETA: 0s - loss: 0.2662 - accuracy: 0.8900
# Epoch 8: val_accuracy improved from 0.62245 to 0.80612, saving model to model_weights.h5
# 8/8 [==============================] - 3s 400ms/step - loss: 0.2662 - accuracy: 0.8900 - val_loss: 0.6031 - val_accuracy: 0.8061
# Epoch 9/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9216
# Epoch 9: val_accuracy improved from 0.80612 to 0.81633, saving model to model_weights.h5
# 8/8 [==============================] - 3s 392ms/step - loss: 0.1889 - accuracy: 0.9216 - val_loss: 0.5177 - val_accuracy: 0.8163
# Epoch 10/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1610 - accuracy: 0.9355
# Epoch 10: val_accuracy did not improve from 0.81633
# 8/8 [==============================] - 3s 332ms/step - loss: 0.1610 - accuracy: 0.9355 - val_loss: 0.5184 - val_accuracy: 0.8163
# Epoch 11/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1293 - accuracy: 0.9418
# Epoch 11: val_accuracy did not improve from 0.81633
# 8/8 [==============================] - 3s 361ms/step - loss: 0.1293 - accuracy: 0.9418 - val_loss: 0.9145 - val_accuracy: 0.7245
# Epoch 12/20
# 8/8 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9671
# Epoch 12: val_accuracy improved from 0.81633 to 0.82653, saving model to model_weights.h5
# 8/8 [==============================] - 3s 395ms/step - loss: 0.0933 - accuracy: 0.9671 - val_loss: 0.5300 - val_accuracy: 0.8265
# Epoch 13/20
# 8/8 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9772
# Epoch 13: val_accuracy improved from 0.82653 to 0.83673, saving model to model_weights.h5
# 8/8 [==============================] - 3s 396ms/step - loss: 0.0786 - accuracy: 0.9772 - val_loss: 0.6492 - val_accuracy: 0.8367
# Epoch 14/20
# 8/8 [==============================] - ETA: 0s - loss: 0.0725 - accuracy: 0.9760
# Epoch 14: val_accuracy improved from 0.83673 to 0.92857, saving model to model_weights.h5
# 8/8 [==============================] - 4s 507ms/step - loss: 0.0725 - accuracy: 0.9760 - val_loss: 0.2569 - val_accuracy: 0.9286
# Epoch 15/20
# 8/8 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9747
# Epoch 15: val_accuracy did not improve from 0.92857
# 8/8 [==============================] - 2s 311ms/step - loss: 0.0768 - accuracy: 0.9747 - val_loss: 0.4648 - val_accuracy: 0.8571
# Epoch 16/20
# 8/8 [==============================] - ETA: 0s - loss: 0.0965 - accuracy: 0.9671
# Epoch 16: val_accuracy did not improve from 0.92857
# 8/8 [==============================] - 2s 307ms/step - loss: 0.0965 - accuracy: 0.9671 - val_loss: 0.4952 - val_accuracy: 0.8469
# Epoch 17/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1101 - accuracy: 0.9520
# Epoch 17: val_accuracy did not improve from 0.92857
# 8/8 [==============================] - 2s 313ms/step - loss: 0.1101 - accuracy: 0.9520 - val_loss: 0.3669 - val_accuracy: 0.8776
# Epoch 18/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1175 - accuracy: 0.9583
# Epoch 18: val_accuracy did not improve from 0.92857
# 8/8 [==============================] - 2s 308ms/step - loss: 0.1175 - accuracy: 0.9583 - val_loss: 0.5386 - val_accuracy: 0.8469
# Epoch 19/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1145 - accuracy: 0.9646
# Epoch 19: val_accuracy did not improve from 0.92857
# 8/8 [==============================] - 3s 366ms/step - loss: 0.1145 - accuracy: 0.9646 - val_loss: 0.2371 - val_accuracy: 0.8980
# Epoch 20/20
# 8/8 [==============================] - ETA: 0s - loss: 0.0670 - accuracy: 0.9772
# Epoch 20: val_accuracy did not improve from 0.92857
# 8/8 [==============================] - 2s 310ms/step - loss: 0.0670 - accuracy: 0.9772 - val_loss: 0.3146 - val_accuracy: 0.8673

# %%
## stats on training data
plt.plot(history.history['loss'], label = 'training loss')
plt.plot(history.history['accuracy'], label = 'training accuracy')
plt.grid(True)
plt.legend()

# %%
## stats on training data
plt.plot(history.history['val_loss'], label = 'validation loss')
plt.plot(history.history['val_accuracy'], label = 'validation accuracy')
plt.grid(True)
plt.legend()

# %%
## lets vizualize results on testing data
AccuracyVector = []
plt.figure(figsize=(30, 30))
for images, labels in testing_data.take(1):
    predictions = model.predict(images)
    predlabel = []
    prdlbl = []

    for mem in predictions:
        predlabel.append(class_names[np.argmax(mem)])
        prdlbl.append(np.argmax(mem))

    AccuracyVector = np.array(prdlbl) == labels
    for i in range(40):
        ax = plt.subplot(10, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title('Pred: '+ predlabel[i]+' actl:'+class_names[labels[i]] )
        plt.axis('off')
        plt.grid(True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
